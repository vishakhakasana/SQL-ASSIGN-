# %% [markdown]
# Write an SQL query to print the FIRST_NAME from Worker table after removing
# white spaces from the right side.
#
# ![SQL%20ASSIGN%203.PNG](attachment:SQL%20ASSIGN%203.PNG)

# %% [markdown]
# Write an SQL query that fetches the unique values of DEPARTMENT from Worker
# table and prints its length.
#
# ![SQL%20ASSIGN%203%282%29.PNG](attachment:SQL%20ASSIGN%203%282%29.PNG)

# %% [markdown]
# Write an SQL query to fetch nth max salaries from a table.
#
# ![SQL%20ASSIGN%203%283%29.PNG](attachment:SQL%20ASSIGN%203%283%29.PNG)
