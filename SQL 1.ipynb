# %% [markdown]
# # Write an SQL query to fetch “FIRST_NAME” from Worker table using the alias
# # name as &lt;WORKER_NAME&gt;.
#
# ![sql%20assign%201.PNG](attachment:sql%20assign%201.PNG)

# %% [markdown]
# # Write an SQL query to fetch unique values of DEPARTMENT from Worker table.
#
# ![sql%20assign%201%282%29.PNG](attachment:sql%20assign%201%282%29.PNG)

# %% [markdown]
# # Write an SQL query to show the last 5 record from a table.
#
#
# ![sql%20assign%201%283%29.PNG](attachment:sql%20assign%201%283%29.PNG)
