# %% [markdown]
# Write an SQL query to print the FIRST_NAME from Worker table after replacing ‘a’
# with ‘A’.
# ![sql%204.PNG](attachment:sql%204.PNG)

# %% [markdown]
# Write an SQL query to print all Worker details from the Worker table order by
# FIRST_NAME Ascending and DEPARTMENT Descending.
# ![sql%204%282%29.PNG](attachment:sql%204%282%29.PNG)

# %% [markdown]
# Write an SQL query to fetch the names of workers who earn the highest salary.
#
# ![sql%204%283%29.PNG](attachment:sql%204%283%29.PNG)
